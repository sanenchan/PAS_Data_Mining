# %%
import numpy as np
import pandas as pd
from apyori import apriori

# %%
store_data = pd.read_excel('D:\dataset\dataset3.xls')

# %%
store_data.head()
# Out:
#             Item1              Item2         Item3              Item4  \
# 0         burgers          meatballs          eggs     low fat yogurt
# 1         chutney     low fat yogurt           NaN  whole wheat pasta
# 2          turkey  whole wheat pasta  french fries               soup
# 3   mineral water               soup   light cream  frozen vegetables
# 4  low fat yogurt  frozen vegetables     spaghetti       french fries
#
#           Item5          Item6            Item7              Item8  \
# 0           NaN  mineral water           salmon     low fat yogurt
# 1  french fries  mineral water           salmon  whole wheat pasta
# 2   light cream        shallot              NaN               soup
# 3     spaghetti      green tea              NaN  frozen vegetables
# 4          eggs      chocolate  frozen smoothie       french fries
#
#           Item9         Item10
# 0           NaN  mineral water
# 1  french fries  mineral water
# 2   light cream        shallot
# ...

# %%
store_data.tail()
# Out:
#                   Item1         Item2            Item3        Item4  \
# 2049            burgers          eggs     french fries   fresh tuna
# 2050            burgers          eggs  frozen smoothie  french wine
# 2051  whole wheat pasta          cake           melons    champagne
# 2052        ground beef  tomato sauce        spaghetti     red wine
# 2053            burgers          eggs  frozen smoothie         milk
#
#           Item5         Item6                Item7          Item8  \
# 2049  spaghetti     olive oil  clothes accessories         turkey
# 2050       eggs  french fries         energy drink   french fries
# 2051   pancakes    light mayo                 soup      chocolate
# 2052      honey      hot dogs               turkey  herb & pepper
# 2053      bacon          eggs         french fries  mineral water
#
#                   Item9         Item10
# 2049               eggs   french fries
# 2050                NaN      chocolate
# ...

# %%
store_data.shape
# Out:
# (2054, 10)

# %%
records = []
for i in range (0,2054):
    records.append([str(store_data.values[i,j]) for j in range (0,10)])

# %%
assosiation_rules = apriori(records, min_support=0.2, min_confidence=0.2, min_lift=0.2, min_lenght=2)

# %%
assosiation_results = list(assosiation_rules)

# %%
print(assosiation_results[0])
# Out:
# RelationRecord(items=frozenset({'avocado'}), support=0.314508276533593, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'avocado'}), confidence=0.314508276533593, lift=1.0)])

# %%
results=[]
for item in assosiation_results:
    pair = item[0]
    items = [x for x in pair]
    
    value0 = str(items[0])    
  #  value1 = str(items[1])
    value2 = str(item[1])[:9]
    value3 = str(item[2][0][2])[:9]
    value4 = str(item[2][0][3])[:9]
    
    rows = (value0,
     #       value1, 
            value2,value3,value4)
    
    results.append(rows)
    
    label = ['tittle 1',
     #        'tittle 2', 
             'support', 'convidence', 'lift']
    
    store_suggestion=pd.DataFrame.from_records(results, columns=label)
    print(store_suggestion)
# Out:
#   tittle 1    support convidence lift
# 0  avocado  0.3145082  0.3145082  1.0
#   tittle 1    support convidence lift
# 0  avocado  0.3145082  0.3145082  1.0
# 1  burgers  0.2429406  0.2429406  1.0
#     tittle 1    support convidence lift
# 0    avocado  0.3145082  0.3145082  1.0
# 1    burgers  0.2429406  0.2429406  1.0
# 2  chocolate  0.4756572  0.4756572  1.0
#               tittle 1    support convidence lift
# 0              avocado  0.3145082  0.3145082  1.0
# 1              burgers  0.2429406  0.2429406  1.0
# 2            chocolate  0.4756572  0.4756572  1.0
# 3  clothes accessories  0.3398247  0.3398247  1.0
#               tittle 1    support convidence lift
# 0              avocado  0.3145082  0.3145082  1.0
# 1              burgers  0.2429406  0.2429406  1.0
# 2            chocolate  0.4756572  0.4756572  1.0
# 3  clothes accessories  0.3398247  0.3398247  1.0
# 4              cookies  0.3588120  0.3588120  1.0
#               tittle 1    support convidence lift
# ...

# %%
store_suggestion.describe()
# Out:
#             tittle 1    support convidence lift
# count             61         61         61   61
# unique            15         53         53    1
# top     french fries  0.2429406  0.2429406  1.0
# freq              25          4          4   61

# %%
store_suggestion.to_excel('D:\dataset\Hasil_dataset3.xls')
